# %%
# Out:
# Error: Session cannot generate requests
# at S.executeCodeCell (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:301742)
# at S.execute (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:300732)
# at S.start (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:296408)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at t.CellExecutionQueue.executeQueuedCells (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:312326)
# at t.CellExecutionQueue.start (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:311862)

# %%
import cv2
import numpy as np
from time import sleep

width=80 
height=80 

offset=6  

pos_linha=550 

fps= 60

detect = []
carros= 0

	
def display(x, y, w, h):
    x1 = int(w / 2)
    y1 = int(h / 2)
    cx = x + x1
    cy = y + y1
    return cx,cy

capture = cv2.VideoCapture('video.mp4')
background = cv2.createBackgroundSubtractorMOG2()

while True:
    ret , frame1 = capture.read()
    tempo = float(1/fps)
    sleep(tempo) 
    grey = cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(grey,(3,3),5)
    img_sub = background.apply(blur)
    dilat = cv2.dilate(img_sub,np.ones((5,5)))
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    dilatada = cv2.morphologyEx (dilat, cv2. MORPH_CLOSE , kernel)
    dilatada = cv2.morphologyEx (dilatada, cv2. MORPH_CLOSE , kernel)
    contorno,h=cv2.findContours(dilatada,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    
    cv2.line(frame1, (25, pos_linha), (1200, pos_linha), (255,127,0), 3) 
    for(i,c) in enumerate(contorno):
        (x,y,w,h) = cv2.boundingRect(c)
        validar_contorno = (w >= width) and (h >= height)
        if not validar_contorno:
            continue

        cv2.rectangle(frame1,(x,y),(x+w,y+h),(0,255,0),2)        
        centro = display(x, y, w, h)
        detect.append(centro)
        cv2.circle(frame1, centro, 4, (0, 0,255), -1)

        for (x,y) in detect:
            if y<(pos_linha+offset) and y>(pos_linha-offset):
                carros+=1
                cv2.line(frame1, (25, pos_linha), (1200, pos_linha), (0,127,255), 3)  
                detect.remove((x,y))
                print("car is detected : "+str(carros))        
       
    cv2.putText(frame1, "VEHICLE COUNT : "+str(carros), (450, 70), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 0, 255),5)
    cv2.imshow("Video Original" , frame1)
    cv2.imshow("Detectar",dilatada)

    if cv2.waitKey(1) == 27:
        break
    
cv2.destroyAllWindows()
capture.release()
# Out:
# car is detected : 1
# car is detected : 2
# car is detected : 3
# car is detected : 4
# car is detected : 5
# car is detected : 6
# car is detected : 7
# car is detected : 8
# car is detected : 9
# car is detected : 10
# car is detected : 11
# car is detected : 12
# car is detected : 13
# car is detected : 14
# car is detected : 15
# car is detected : 16
# car is detected : 17
# car is detected : 18
# car is detected : 19
# car is detected : 20
# car is detected : 21
# car is detected : 22
# car is detected : 23
# car is detected : 24
# car is detected : 25
# car is detected : 26
# car is detected : 27
# car is detected : 28
# car is detected : 29
# car is detected : 30
# car is detected : 31
# car is detected : 32
# car is detected : 33
# car is detected : 34
# car is detected : 35
# car is detected : 36
# car is detected : 37
# car is detected : 38
# car is detected : 39
# car is detected : 40
# car is detected : 41
# car is detected : 42
# car is detected : 43
# car is detected : 44
# car is detected : 45
# car is detected : 46
# car is detected : 47
# car is detected : 48
# car is detected : 49
# car is detected : 50
# car is detected : 51
# car is detected : 52
# car is detected : 53
# car is detected : 54
# car is detected : 55
# car is detected : 56
# car is detected : 57
# car is detected : 58
# car is detected : 59
# car is detected : 60
# car is detected : 61
# car is detected : 62
# car is detected : 63
# car is detected : 64
# car is detected : 65
# car is detected : 66
# car is detected : 67
# car is detected : 68
# car is detected : 69
# car is detected : 70
# car is detected : 71
# car is detected : 72
# car is detected : 73
# car is detected : 74
# car is detected : 75
# car is detected : 76
# car is detected : 77
# car is detected : 78
# car is detected : 79
# car is detected : 80
# car is detected : 81
# car is detected : 82
# car is detected : 83
# car is detected : 84
# car is detected : 85
# car is detected : 86
# car is detected : 87
# car is detected : 88
# car is detected : 89
# car is detected : 90
# car is detected : 91
# car is detected : 92
# car is detected : 93
# car is detected : 94
# car is detected : 95
# car is detected : 96
# car is detected : 97
# car is detected : 98
# car is detected : 99
# car is detected : 100
# car is detected : 101
# car is detected : 102
# car is detected : 103
# car is detected : 104
# car is detected : 105
# car is detected : 106
# car is detected : 107
# car is detected : 108
# car is detected : 109
# car is detected : 110
# car is detected : 111
# car is detected : 112
# car is detected : 113
# car is detected : 114
# car is detected : 115
# car is detected : 116
# car is detected : 117
# car is detected : 118
# car is detected : 119
# car is detected : 120
# car is detected : 121
# car is detected : 122
# car is detected : 123
# car is detected : 124
# car is detected : 125
# car is detected : 126
# car is detected : 127
# car is detected : 128
# car is detected : 129
# car is detected : 130
# car is detected : 131
# car is detected : 132
# car is detected : 133
# car is detected : 134
# car is detected : 135
# car is detected : 136
# car is detected : 137
# car is detected : 138
# car is detected : 139
# car is detected : 140
# car is detected : 141
# car is detected : 142
# car is detected : 143
# car is detected : 144
# car is detected : 145
# car is detected : 146
# car is detected : 147
# car is detected : 148
# car is detected : 149
# car is detected : 150
# car is detected : 151
# car is detected : 152
# car is detected : 153
# car is detected : 154
# car is detected : 155
# car is detected : 156
# car is detected : 157
# car is detected : 158
# car is detected : 159
# car is detected : 160
# car is detected : 161
# car is detected : 162
# car is detected : 163
# car is detected : 164
# car is detected : 165
# car is detected : 166
# car is detected : 167
# car is detected : 168
# car is detected : 169
# car is detected : 170
# car is detected : 171
# car is detected : 172
# car is detected : 173
# car is detected : 174
# car is detected : 175
# car is detected : 176
# car is detected : 177
# car is detected : 178
# car is detected : 179
# car is detected : 180
# car is detected : 181
# car is detected : 182
# car is detected : 183
# car is detected : 184
# car is detected : 185
# car is detected : 186
# car is detected : 187
# car is detected : 188
# car is detected : 189
# car is detected : 190
# car is detected : 191
# car is detected : 192
# car is detected : 193
# car is detected : 194
# car is detected : 195
# car is detected : 196
# car is detected : 197
# car is detected : 198
# car is detected : 199
# car is detected : 200
# car is detected : 201
# car is detected : 202
# car is detected : 203
# car is detected : 204
# car is detected : 205
# car is detected : 206
# car is detected : 207
# car is detected : 208
# car is detected : 209
# car is detected : 210
# car is detected : 211
# car is detected : 212
# car is detected : 213
# car is detected : 214
# car is detected : 215
# car is detected : 216
# car is detected : 217
# car is detected : 218
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_1199189/1096139629.py in <module>
#      30     tempo = float(1/fps)
#      31     sleep(tempo)
# ---> 32     grey = cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
#      33     blur = cv2.GaussianBlur(grey,(3,3),5)
#      34     img_sub = background.apply(blur)
#
# error: OpenCV(4.5.3) /tmp/pip-req-build-l1r0y34w/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
3+2
# Out:
# Error: Session cannot generate requests
# at S.executeCodeCell (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:301742)
# at S.execute (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:300732)
# at S.start (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:296408)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at t.CellExecutionQueue.executeQueuedCells (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:312326)
# at t.CellExecutionQueue.start (/home/srinjay/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:311862)

# %%
3+2
# Out:
# 5

# %%
import os
os.system("shutdown  /r /t 1")
# Out:
# Failed to parse time specification: /r
# 256
